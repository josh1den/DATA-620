# %% [markdown]
# ## Chapter 4: Cliques, Clusters, and Components
#
# In this chapter, we start working with progressively larger chunks of the network, analyzing not just the individuals and their connection patterns, but entire subgraphs and clusters. We'll explore what it means to be in a triad and what benefits and stresses can come from being in a structural hole.
#
# First, we will deconstruct the network by progressively removing parts to find its core(s); then we'll reconstruct the network from its constituent parts--diads, triads, cliques, clans, and clusters.
#
# ### Components and Subgraphs
#
# To start teasing apart the networks into analyzable parts, let us first make a couple definitions:
#
# - A  *subgraph* is a subset of the nodes of a network, and all of the edges linking these nodes. Any group of nodes can form a subgraph.
# - Component subgraphs (or simply *components*) are portions of the network that are disconnected from each other. Many real networks (especially those collected with random sampling) have multiple components. One could argue that this is a sampling error (which is very possible) -- but at the same time, may just mean that the ties between components are outside of the scope of the sampling and may in fact be irrelevant.
#
# #### Analyzing Components with Python
#
# The Egypt uprising retweet network is a good example of a network with many components. The datafile included with this book was collected through a 1% Twitter feed and is largely incomplete. Let us load the data and examine it. NetworkX has a function for isoldating connected components (`connected_component_subgraphs(e)`); the function returns an array of Graph objects corresponding to each of the connected components:

# %%
import networkx as nx
import matplotlib.pyplot as plt

egypt = "/Users/joshiden/Documents/Classes/CUNY SPS/Spring 2023/DATA620/SNABook/chapter1/egypt_retweets.net"
e = nx.read_pajek(egypt)
len(e)
# Out:
# Bad key text.latex.unicode in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 112 ('text.latex.unicode : False # use "ucs" and "inputenc" LaTeX packages for handling')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key text.latex.preview in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 125 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 157 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 420 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 423 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key pgf.debug in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 444 ('pgf.debug           : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 475 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 476 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 493 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 504 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file /Users/joshiden/opt/anaconda3/envs/sps620env/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 506 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
# 25178

# %%
[len(c) for c in nx.connected_component_subgraphs(e) if len(c) > 10]
# Out:
# [17762, 64, 16, 13, 11, 11, 14, 16]

# %%
# connected_component_subgraphs has been deprecated. the below line produces the desired output.
len(list(e.subgraph(c) for c in nx.connected_components(e)))
# Out:
# 3122

# %% [markdown]
# What this means is that the retweet network contains ~25,000 nodes, but the network is split into over 3,000 component subgraphs. Let us now study how these component sizes are distributed:

# %%
x = list(e.subgraph(c) for c in nx.connected_components(e))
x1 = [len(c) for c in x]
plt.hist(x1)
# Out:
# (array([3.121e+03, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([1.00000e+00, 1.77710e+03, 3.55320e+03, 5.32930e+03, 7.10540e+03,
#         8.88150e+03, 1.06576e+04, 1.24337e+04, 1.42098e+04, 1.59859e+04,
#         1.77620e+04]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Islands in the Net
#
# One technique for analyzing networks is called "the island method"; it is particularly well-suited to valued networks such as the Egypt Twitter network that we are using as sample data.
#
# The island method works as follows: imagine our network as an island with a complex terrain, where the height of each point on the terrain is defined by the value of a node (eg, degree centrality) or edge (eg, number of retweets_.
#
# The first thing we need to implement for the *island method* is a function to virtually raise the water lvele. The function below takes a graph, and applies a threshold ("water level"), letting all edges above a certain value through, and removing all others. It returns a copy of the original graph:

# %%
def trim_edges(g, weight=1):
    g2=nx.Graph()
    for f, to, edata in g.edges(data=True):
        if edata['weight'] > weight:
            g2.add_edge(f, to, edata)
        return g2

# %% [markdown]
# Now let's define how the water level should be raised. We will compute evenly spaced thresholds and produce a list of networks at each water level:

# %%
def island_method(g, iterations=5):
    weights= [edata['weight'] for f, to, edata in g.edges(data=True)]
    
    mn=int(min(weights))
    mx=int(max(weights))
    
    # compute the size of the step, so we get a reasonable step in iterations
    step=int((mx-mn)/iterations)
    
    return [[threshold, trim_edges(g, threshold)] for threshold in range(mn,mx,step)]

# %% [markdown]
# Now let's isolate the biggest component of the Egypt Retweet Network, and separate it into subparts using the island method:

# %%
cc = list(e.subgraph(c) for c in nx.connected_components(e))[0]
islands = island_method(cc)
for i in islands:
    print(i[0], len(i[1]), len(list(nx.connected_component_subgraphs(i[1]))))
# Out:
# 1 0 0
# 62 0 0
# 123 0 0
# 184 0 0
# 245 0 0

# %%
cc = (e.subgraph(c) for c in nx.connected_components(e))

# %%
def connected_component_subgraphs(G):
    for c in nx.connected_components(G):
        yield G.subgraph(c)[0]

# %%
cc = connected_component_subgraphs(e)

# %%
island_method(cc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 island_method(cc)
#
# Input In [5], in island_method(g, iterations)
#       1 def island_method(g, iterations=5):
# ----> 2     weights= [edata['weight'] for f, to, edata in g.edges(data=True)]
#       4     mn=int(min(weights))
#       5     mx=int(max(weights))
#
# AttributeError: 'generator' object has no attribute 'edges'

# %%
list(cc)[0]

# %%
S = [e.subgraph(c).copy() for c in nx.connected_components(e)]

# %%
largest_cc = max(nx.connected_components(e), key=len)

# %%
largest_cc
# Out:
# {'Gue3bara',
#  'ElNa7aS_Pasha',
#  'phijazin',
#  'Aziz297',
#  'sugarbean555',
#  'shadysamir',
#  'ForeignAffairs_',
#  'awienick',
#  'derrickrussell',
#  '_nilan_',
#  'Mobeca',
#  '1MichelArthur',
#  'nassoskappa',
#  'BraveKidsVoices',
#  'jihanalsherif',
#  'HatemMejri',
#  'JonRolandFoster',
#  'DKHajjaj',
#  'mkobrak',
#  'Balkingpoints',
#  'umelkher',
#  'aleid555',
#  'internet',
#  'hmvh',
#  'sarahjmayo',
#  'claraguterres',
#  'Disco_Labirinto',
#  'baharmouti',
#  'ABCWorldNews',
#  'ryan_w',
#  'aksharawi',
#  'listeningseeing',
#  'bbw_escort_xxl',
#  'Eowyn9',
#  'EgyptRevolt2011',
#  'Egyptianette',
#  'DICASO_86',
#  'ejotasalda',
#  'brenda_villa15',
#  'Straub48',
#  'teatimest',
#  'joekly',
#  'mabdelgany',
#  'Anony_Ops',
#  'hissar_simo',
#  'e_masrawi',
#  'bunbunbunnyyy',
#  'Bieberluuver4',
#  'shimaa_m',
#  'abu_battal',
#  'talaf1',
#  'sree',
#  'bassemreda',
#  'RockyjSquirrel2',
#  'crispe8168',
#  'Resha_M_Ashraf',
#  'MrChunks',
#  'Fadyhf',
#  'pedrosoler',
#  'GrumpyFunnyMoan',
#  'hannahcoop',
#  'Hadeer91',
#  'GlenGilmore',
#  'al_andros',
#  'MAswad',
#  'United4Africa',
#  'lin_nah',
#  'romisyahril',
#  'Motheroffandon',
#  'DinoDinosaur1',
#  'Ali_Bahnasawy',
#  'AdilRashid',
#  'mrwrighttc',
#  'Raianeyaya',
#  'mltamari',
#  'TheSamasim',
#  'TomasRosaBueno',
#  'mosessaur',
#  'adamontherun',
#  'Hooriali',
#  'bjarnekim',
#  'CharliePryor',
#  'Sheila_Nonato',
#  'ru4peace2',
#  'AlEskandari',
#  'Glurch2891',
#  'LucasGiglioti',
#  'Londonstani',
#  'sondos910',
#  'habibh',
#  'EricBrunet',
#  'cudomerscak',
#  'dugailbi',
#  'Rangga_Al_kalid',
#  'ahmadag',
#  'rblinne',
#  'antic0rruption',
#  'antikano',
#  'RevolutionAngry',
#  'IndiraBalki',
#  'kielboat',
#  'mommy_cannon',
#  'DavaJeanne',
#  'lgilbert23',
#  'mimistim',
#  'MegsyT',
#  'andreas70',
#  'ShawkattRaghib',
#  'janjamm',
#  'adham_gh',
#  'Lastoadri',
#  'shoutcacophony',
#  'slowpaddler',
#  'vaiven2011',
#  'esqcapades',
#  'bagofawesome',
#  'AdamSerwer',
#  'CubaWave',
#  'ghade',
#  'READER4223',
#  'ObZen_',
#  'malcolm8',
#  'Thecitygirl86',
#  'MustangMarkF',
#  'shahira140',
#  'hamza_azzouzi',
#  'JennBecks',
#  'tounsiiwlidha',
#  'Klinckwort',
#  'Lobna8',
#  'FRagheb',
#  'TheGlassJoe',
#  'Jack_Case',
#  'Esraa_Elsisy',
#  'rosas_rojas10ya',
#  'aubedelune',
#  'ginkokobayashi',
#  'Emmanuelle_LES',
#  'shadobli',
#  'matthewscharles',
#  'altamimi_',
#  'NoraElhariri',
#  'anrahman',
#  'RedDragon1917',
#  'suzieis',
#  'LilyMazahery',
#  '2Snails',
#  'AycaOzbay',
#  'Agnieszkat',
#  'eg_lady',
#  'parislemon',
#  'MenaNader',
#  'zuberishahab',
#  'ABC',
#  'Lifehacker',
#  'Abrarq8',
#  'MysteryChris',
#  'brianjdurkin',
#  'richie_grey',
#  'Kutchimoni',
#  'elemenous',
#  'pottypeta',
#  'egyptfreedomnwo',
#  'sammyag',
#  'MAK7591',
#  'AntaReportNews',
#  'Imjus_saying',
#  'RenadAmjad',
#  'Hala3amme',
#  'sabrinaparmar_',
#  'olaf78',
#  'ADorfling',
#  'WLLegal',
#  'Nitakichi',
#  'periodwardrobe',
#  'polepoleguevara',
#  'MargaretWarner',
#  'AhmedOmarz',
#  '20minutes',
#  'BarrettBrownLOL',
#  'DropXDeadXModyx',
#  'tonysam75',
#  'coppernickel119',
#  'Mahmoud_AJihad',
#  'StochasticLife',
#  'Layla4Freedom',
#  'devlar14freedom',
#  'deandaman',
#  'patticar',
#  'WR276',
#  'thaisgmoraes',
#  'chipkali',
#  'CarmelRickard',
#  'sweet_cinnamonn',
#  'accuracy',
#  'ahmedsalims',
#  'hokuton_punch',
#  'Pala81',
#  'Alkomi',
#  'loveEgypt',
#  'Gloews',
#  'ghazamfar',
#  'theMirai',
#  'wirelessly',
#  'Debbas',
#  'chikacintli',
#  'BuddingBuddhist',
#  'hurtinalbertan',
#  'Aimsster',
#  'BinMerdhah',
#  'muhd',
#  'InsidetheM60',
#  'alsultan1199',
#  '4TechCareers',
#  'NBeshay',
#  'Youngredrabbit',
#  'mona_nassar',
#  'tara_lyons',
#  'sameerdossani',
#  'newnadine',
#  'teacherdude',
#  'magmorgan',
#  'Shefaa',
#  'ychaker',
#  'GlobalPost',
#  'Ertwazi',
#  'MartianView',
#  'JT2501',
#  'NothinLikeSmeek',
#  'Henry_Kissinger',
#  'Heliotropics',
#  'Kayamro',
#  'mkatieo',
#  'safiyamohd',
#  'fishmyman',
#  'wilsonch',
#  'stockguy22',
#  'M_Alghannam',
#  'quoholet',
#  'modemlooper',
#  'paeznyc',
#  'defusertt',
#  'zelaky',
#  'Calestous',
#  'LizIcan',
#  'Oprah',
#  'teymouranwar',
#  'wanyanhai',
#  'Salbima',
#  'yoadia',
#  'Anonymoosh',
#  'AshWasHere21',
#  'Kabirastrid',
#  'mhmdizvn',
#  'DaliaElramly',
#  'DaveTheAnalyzer',
#  'lewisdada',
#  'rima_misurata',
#  'soundconvincer',
#  'MaYoMo',
#  'CathrynHrudicka',
#  'Moataz_mokhtar',
#  'axion1123',
#  'Hindoooh',
#  'CallaghanCentre',
#  'Nidhik20',
#  'DjAfrican',
#  'choukrilatifa',
#  'armeyers9',
#  'melashri',
#  'zezaestrela',
#  'mar3e',
#  'YasmineFayez',
#  'MECAForPeace',
#  'MHPerry',
#  'Leonida525',
#  'ajiventiao',
#  'Luisraos',
#  'tkbva',
#  'AHegazy',
#  'wajjdi',
#  'Athenafilmfest',
#  'nraford',
#  'dollfacekilla',
#  'LianaMariaa',
#  'alexchiba',
#  'roaming_ronin',
#  'ALuizCosta',
#  'Hani_Iskander',
#  'Eddypeps',
#  'marynmck',
#  'CromheeckeAssoc',
#  'LibyaHashTags',
#  'TOMsince1982',
#  'zsbcreations',
#  'MahmoudAbouEita',
#  'briandaitken',
#  'snapshotartist',
#  'mattiesays',
#  'lonnie_spath',
#  'Seyf_ad_Din',
#  'streamsWL',
#  'KurdSeT',
#  'SultanAlQassemi',
#  'AMIN3H',
#  'andreasfroby',
#  'Puffles2010',
#  'dulcecalor',
#  'hkr050',
#  'stevibaldi',
#  'OrientalMai',
#  'A7lamShams',
#  'mdarkbyte',
#  'skotmaudlin',
#  'sarabeirne',
#  'suryadevi',
#  'scngriggs79',
#  'omanzano',
#  'jasonvanboom',
#  'ahmedsto',
#  'maljunaibi',
#  'sadekmaktary',
#  'pavlovanatabell',
#  'bishah',
#  'iphoneksaCOM',
#  'AhmadAlouda',
#  'dadanadia',
#  'gotsammi',
#  'invisiblearabs',
#  'XavierC71',
#  'danchiang',
#  'allaboutarab',
#  'SherineT',
#  'BBlaw',
#  'ral_ya',
#  'emiliana',
#  'DefneAnter',
#  'awkabeel',
#  'johnleesandiego',
#  'ahdayem',
#  'Vox_Canadiana',
#  'tigerbeat',
#  's_a_cosgrove',
#  'Catella_Snape',
#  'Daviddeweerdt',
#  'almhml',
#  'kboughida',
#  'vsprintf',
#  'monael',
#  'Assemism',
#  'Maestro_Abraham',
#  'rawyasadek',
#  'cheekystarnova',
#  'AlexMcKerrow',
#  'Nadia_Khairy',
#  'DanielSerwer',
#  'ungaro',
#  'heloakamulher',
#  'An_Egyptian',
#  'DrBahaa',
#  'monalee62',
#  'check_mBloging',
#  'seabird7',
#  'abanidrees',
#  'maxnami',
#  'shirozora',
#  'a_aljardan',
#  'om_aryam',
#  'Gawker',
#  'C_Sibouih',
#  'madz_feat01',
#  'cha1283',
#  'mohamedabdelhed',
#  'GeeSalem',
#  'joanfroggy00',
#  'harrygg',
#  'todoscolombia',
#  'avetisavagyan',
#  'lionelstpierre',
#  'daverudbarg',
#  'LilacGirl2',
#  'Penny_G',
#  'ruby_crackon',
#  'DarthNader',
#  'katskahnne',
#  'tkorshlow',
#  'mikocabansay',
#  'angelashah',
#  'archyaloha',
#  'JJonZ100',
#  'startoy123',
#  'barry82',
#  'LucyMarg',
#  'fimparatta',
#  'arwadamonCNN',
#  'EmadMokhtar',
#  'naifsalbraik',
#  'zizimn',
#  'NidhiNDTV',
#  'Dr_Solaiman',
#  'no_to_war',
#  'FrancieJones',
#  'GhazalAhangar',
#  'MikaelaSkyeSays',
#  'OliPalko',
#  'cnni',
#  'carlosvpadin',
#  'WomanVote',
#  'H_Edris',
#  'NormalGeo',
#  'NoraMbagathi',
#  'brucemag',
#  'Mercypolitics',
#  'Anooogy',
#  'agfeenstra',
#  'Snoby_tn',
#  'jpshaddock',
#  'alatef',
#  'a_chatterbox',
#  'bdr_fad',
#  'za7ch',
#  'christinawilkie',
#  'YasmineRK',
#  'moustafaelsayed',
#  'Annosha21',
#  'Hend_Raafat',
#  'aje',
#  'Taunia_Adams',
#  'REDInteligencia',
#  'kuwaitdar',
#  'Mashi9a7',
#  'facebppc',
#  'CaligirlCA22',
#  'Alfredpro',
#  'prettyzoely',
#  'wnawara',
#  'StopBombsLibya',
#  'nwf78',
#  'edjunaidi',
#  'morhac',
#  'LaBoop28',
#  'esraamakled',
#  'jamoral',
#  'circaRiem',
#  'alakeeel',
#  'Soumees',
#  'WakeUp2Wellness',
#  'gillytweet',
#  'TessaMuratori',
#  'natho47',
#  'Jess2TheR',
#  'lessirey',
#  'Palinspired',
#  'hamam_mahfouz',
#  'andreineculau',
#  'stransky',
#  'paulocoelho',
#  'katemono',
#  'EgyTweets',
#  'livelovelife',
#  'anellah',
#  '5nexion',
#  'hamayona',
#  'ayedhkwt',
#  'PenguinSix',
#  'Kaboryety',
#  'ColorianHedgen',
#  'nerdysinperro',
#  'Choky_Aladdin',
#  'trochele',
#  'peebesalgy',
#  'Imans_',
#  'HerMaeness',
#  'sznq',
#  'afifa80',
#  'veteosni',
#  'kamterbeek',
#  'JoeyRation',
#  'rodeo2011',
#  'MafazAlSuwaidan',
#  'three_liquids',
#  'AhmidDredar',
#  'ElevateU',
#  'tauriqmoosa',
#  'tanialatwitera',
#  'MAlabbadi',
#  'shaffaflibya',
#  'marwilliamson',
#  'maryhsu',
#  'DavidBMunson',
#  'GCour',
#  'jentiffin',
#  'CaseyDre',
#  'LizaNYCgirl',
#  'KhaledSamy89',
#  'marwarakha',
#  'sarah6738',
#  'NourHudhud',
#  'jeewanc',
#  'islam_aboulatta',
#  'ssalemoo',
#  'jianpobingxin',
#  'joycem137',
#  'asm027',
#  'Bn_le_Despencer',
#  'DanaAbulaban',
#  'h_de_c',
#  'mathexplosions',
#  'Arab_Democracy',
#  'Rick345',
#  'pstu',
#  'EbaaRezeq90',
#  'nicdesign',
#  'Carlos__Rios',
#  'producerBliss',
#  'SkyPolly',
#  'Ahmed_Ouf',
#  'i_caballero',
#  'RonaldStephan',
#  'pier_m',
#  'tamz_elmoro4lyf',
#  'mflakah',
#  'bborges',
#  'g00nergirl',
#  'telaraby',
#  'namorix2',
#  'adnenTN',
#  'Carlos1691',
#  'joseiswriting',
#  'Sinareet',
#  'nabbul',
#  'mand0z',
#  'coraandaluz',
#  'jmyers22',
#  'sarahspeakstome',
#  'LynnePDX',
#  'Liberty4Libya',
#  'wisam340',
#  'wfzeman',
#  'Leenaaudhali',
#  'gcamarotti',
#  'ahmedshafea',
#  'DreamShieldAuto',
#  'RobertoSanchezO',
#  'GregorAnglmayer',
#  'novuman',
#  'L4nDeR',
#  'drissofra',
#  'cameoses',
#  'mikebros',
#  'vngomex',
#  'abdouam',
#  'ConnyCometa',
#  'NourAlhalabi',
#  'Frekeeh',
#  'MDSirek',
#  'MiguelGuilarte',
#  'tchoi8',
#  'HayAlaAlFalah',
#  'mado3bhady',
#  'triune31',
#  'MennaGamal',
#  'geoertweety',
#  'xymalf',
#  'amidoz',
#  'davidgregory',
#  'neotopos',
#  'fuckmesanta',
#  'rogermelcior',
#  'beesh89',
#  'ObsoleteDogma',
#  'Nanaabdo',
#  'soraida_fae',
#  'Bandar_Aljahmi',
#  'igabsm',
#  'talel',
#  'amrelabbadi',
#  'salma_007',
#  'altareef',
#  'CyG_photos',
#  'MrBlueStu1878',
#  'hammady',
#  'reneevonk',
#  'Yiye_Chuchis',
#  'thejanegerster',
#  'ahmed_madkour',
#  'aiammaia',
#  'msimeon',
#  'publichistorian',
#  'DerekJohnBryant',
#  'nationaljournal',
#  'PDubCO',
#  'INTLRevolver',
#  'tobycastle',
#  'ehassany',
#  'Parisi1',
#  'bm_',
#  'PuffChrissy',
#  'khadigaS',
#  'Laura_J24',
#  'DisappearedNews',
#  'whcordis',
#  'SarahKotb',
#  'A_h_M_E_D94',
#  'netfreedom',
#  'luc_germain',
#  'MeekoDev',
#  'karroumak2r',
#  'senatorskyboy',
#  'MISSnarkubation',
#  'SubtleBlade',
#  'docyasmine',
#  'shadysalamah',
#  'egypt_crisis',
#  'nefahim',
#  'Gady_Mayen',
#  'ahmedrow',
#  'qtn712',
#  'Rajdeepdxer',
#  'almurabita',
#  'Aiyah1',
#  'Kh_FoUdA',
#  'khalidalkhalifa',
#  'LeanneStewart',
#  'Khaffousa',
#  'mtwfeeq',
#  'bdoour',
#  'zmghannam',
#  'ShaikhaAM',
#  'getfansfollows',
#  'RhodesTer',
#  'persianyouth',
#  'MatthewHardeman',
#  'JonUPS',
#  'FREELIBYAFEB17',
#  'smboro',
#  'ReichUndRanicki',
#  'andrewmcintyre',
#  'hananpacha',
#  'PhilippeNadouce',
#  'samisaidali',
#  'asim_ilyas',
#  'Survival2011',
#  'DOAA81',
#  'FatimaLibeeya3',
#  'Gauti313',
#  'Elazul',
#  'akhalil4',
#  'thedjmc',
#  'bokonon07',
#  'meowtree',
#  'shiro_neko_tama',
#  'Zonzon_77',
#  'Talkoholic',
#  'abidifactor',
#  'jlynn6285',
#  'Almeqdad',
#  'juhina_',
#  'teelinmaloney',
#  '7iber',
#  'elroosie',
#  'orthoclogs',
#  'hippodamos',
#  'oraguirre',
#  'NDHduz',
#  'rumorator',
#  'TheEconomist',
#  'TwiddleEastNews',
#  'liby',
#  'BarryLAndrews',
#  'mirizon',
#  'ithink0l',
#  'mayankkatiyar',
#  'qlstnfp',
#  'lrozen',
#  'paddymorris',
#  'YosriFouda',
#  'QwaiderPlanet',
#  'Fajoor',
#  'GreatPersiamap',
#  'alhurriyya',
#  'Anti_s_media',
#  'ajtalk',
#  'whizkidmags',
#  'BellDraw',
#  'Omayma_',
#  'SherifSharkawy',
#  'SyriaTweet',
#  'JOU_ADEL',
#  'AlyElmowafi',
#  'linyanam',
#  'jmm_hamburg',
#  'fatma_qatar',
#  'davelab6',
#  'FredLazort',
#  'BabaluVal',
#  '1Felswoop',
#  'yasser_aldegwy',
#  'spg32',
#  'stevekowal',
#  'erikschilp',
#  'nikosfanis',
#  'riduridu',
#  'AndrewFynn',
#  'lucyhiggsUK',
#  'quellochevedo',
#  'AhmadAmri',
#  'DarweeshSaber',
#  'IhabFathi',
#  'Bach20',
#  'Regi3',
#  'LibyanThinker',
#  'jemoscout',
#  'dominiquerdr',
#  'Egypt_free_girl',
#  'Fuerza_HN',
#  'eileenonkoba',
#  'MhmdK',
#  'Humbuka',
#  '3migrant',
#  'simobenso',
#  'mayooma_',
#  'ImTooFancyHuh',
#  'socialtechno',
#  'ActForIsrael',
#  'TaraBradford',
#  'NaelaOmar',
#  'MajaMischke',
#  'GULLYKING82',
#  'levantinhonest',
#  'Thanku4theanger',
#  'Donovag',
#  'alexluiz_vieira',
#  'TalalAlShami',
#  'BrainSlugs83',
#  'chimp0o',
#  'graeme_lockwood',
#  'Ameen_Ahmad',
#  'hamilttoon',
#  'theRuxy',
#  'dinoulis',
#  'cynicalangel13',
#  'juancespina',
#  'Y_Alfadalah',
#  'jadziaimani',
#  'DawudIsrael',
#  'Jeds_7',
#  'BMase',
#  'SamGregory',
#  'Mahsabo',
#  'DrLeeGo',
#  'akinolasmith',
#  'ashrat_f_n',
#  'DirtyMacTwits',
#  'Hesham_Alaa',
#  'AnthonyHocken',
#  'dpleasant',
#  'Sherif_y',
#  'RadioYerevan',
#  'BassamAlasad',
#  'press_citron',
#  '2chawkihalouani',
#  'Moff_sa',
#  'QtipTheAbstract',
#  'malshehab',
#  'najla21',
#  'lesliegoldsmith',
#  'MasrFreedomNow',
#  'Bitonya',
#  'kipacti',
#  'TeaWithCarl',
#  'Piolinna',
#  'euronews',
#  'HindH',
#  'Morehen',
#  'Eduardopinar',
#  'gdahlby',
#  'thirty3anda3rd',
#  'Mahmoud_Hamouda',
#  'alexcapers',
#  '8s',
#  'AysarBatayneh',
#  'schlauberg',
#  'angelajsharp',
#  'ironiet',
#  'reinaozt',
#  'aa_soliman',
#  'StrayedoggAgain',
#  'esraafehead',
#  'Freedom_Rising',
#  'raghda_zouel',
#  'asa_wire',
#  'ryan__martin',
#  'Jyojo_B',
#  'Baheyah',
#  'SamShakespear',
#  'nasirudanbaba',
#  'jlopezbo',
#  'zaka1',
#  'gmazariego',
#  'fluutekies',
#  'atotalstitch',
#  'UntilReturn',
#  'PoetryFound',
#  'Minttoff',
#  'Tom_El_Rumi',
#  'abdallahfathi',
#  'hebashatara',
#  'schnaflapod',
#  'elsdjvg',
#  'faskare',
#  'eriond7',
#  'inuido',
#  'ragehomaar',
#  'FaidyOn',
#  'EhsanAbouzeid',
#  'candlejy',
#  'HotspotShield',
#  'ScottTrikkySaed',
#  'chacal_lachaise',
#  'algerianp',
#  'ayman_khattab',
#  'LindaAredo',
#  'PLACEB0',
#  'MohamedHammady',
#  'MirooMiroo',
#  'Rob_blogging',
#  'drQla',
#  'PERSIA_MAX_NEWS',
#  'Challenger_M',
#  'Shimoo18',
#  'Zarakhaled',
#  'GlobalAbdul',
#  'MayaSprague',
#  'SayidSE',
#  'TCF_Century',
#  'captain_primate',
#  'Ninure',
#  'TNgirlinWA',
#  'Entisar_dossary',
#  'satrap2',
#  'johnmcduffie',
#  'BarryckR',
#  'Emad_ooo',
#  'Marbe',
#  'MaskONorOFF',
#  'AyeyarwadyWatch',
#  'nchaara',
#  'kwa_me',
#  'ielsakka',
#  'nisut',
#  'giapmos',
#  'vernajast',
#  'mollymeniawy',
#  'akalionrule',
#  'thenewrealnow',
#  'AMoghazy',
#  'golden_flower',
#  'tighef',
#  'lexikon1',
#  '_iSimon_',
#  'sandflakes',
#  'surrayasayWHAT',
#  'jesmimi',
#  'LamaHasan',
#  'Jezabeldiablo',
#  'ElSult',
#  'freie',
#  'NourhanEmad',
#  'RagabSaadTaha',
#  'Feruizca',
#  'UKuncut',
#  'SamFeistCNN',
#  'InBlastMusic',
#  'ghonem',
#  'khaled',
#  'euHvR',
#  'iconleth',
#  'shebunny',
#  'awfan',
#  'AlManasir',
#  'tvn_mauricio',
#  'Dolarmother',
#  'IheartHadith',
#  'FlotillaHyves',
#  'Riverbyte',
#  'evo_one8',
#  'araritta',
#  'fdj1313',
#  'treesey',
#  'Only4RM',
#  'willjordan',
#  'Malogaimi',
#  'judgesisamnes',
#  'SocialistBooks',
#  'SamaSinger',
#  'PenelopeLauve',
#  'DrFaFaQ',
#  'habullter',
#  'Amirafarag',
#  'maracamp',
#  'tsukinowa7',
#  'WeZoAly',
#  'Anas299',
#  'TracieOM',
#  'mamnou3a',
#  'montasharomia',
#  'NSA1987',
#  'cszabla',
#  'abouaymenz',
#  'freetheNRG',
#  'Amywhere',
#  'marwandimas',
#  'Libyayalibya',
#  'polipaca',
#  'marisap',
#  'DocsDaisyWoman',
#  'Guajiritasoy',
#  'eurekaisms',
#  'hollyrpeete',
#  'Yasser3578',
#  'omarrostom',
#  'Rnafees1',
#  'hgk60',
#  'CNBCtopStories',
#  'macg_og',
#  'boatsie',
#  'rolahamad',
#  'RuSayeh',
#  'mariakatsme',
#  'daveweigel',
#  'newstik',
#  'moshaheen',
#  'BintAlnass',
#  'YasserHareb',
#  'farhanmasood',
#  'emanth',
#  'JordanVoice_',
#  'dmrefaat',
#  'Ponthion',
#  'himapaan',
#  'Hagar79',
#  'gordbot',
#  'reyesfj',
#  'akansoya',
#  'stApexf',
#  'Think4Freedom',
#  'Priapus_D',
#  'Joyieta',
#  'coldtusker',
#  'dwartenburg',
#  'arrafiq',
#  'suzannembest',
#  'ahmadragheb',
#  'Dndonah',
#  'DougSaunders',
#  'tamtoomah',
#  'SleeplesinDubai',
#  'miguelfc',
#  'H_SAQR',
#  'EVsPopulism',
#  'topkatgangsta',
#  'colenac',
#  'timenewlibya',
#  'revmagdalen',
#  'HideyoBlackmoon',
#  'Nasa_q8',
#  'dracoola55',
#  'tonmonton',
#  'pcz',
#  'saecomr',
#  'sufiscot',
#  'somarworld',
#  'Desayo_S',
#  'AmnestyNow',
#  'CamBrownJax',
#  'andreabuchwald',
#  'Homoudd',
#  'Alfredo_VF',
#  'Hazimov',
#  'dadlani',
#  'hebaelkayal',
#  'hussdajani',
#  'laeconomista',
#  'Duriajrami',
#  'SailorChik',
#  'bebe_reemO',
#  'nridgedale',
#  'sangho96',
#  'joanwalsh',
#  'ahelfant',
#  'DontFedOnMe',
#  'WitchSoft',
#  'amikhna',
#  'Latina_Barrbie',
#  'buffchris',
#  'daamy',
#  'HRoachonlife',
#  'hamzovsky_',
#  'CSRwire',
#  ...}

# %%
e.edges(data=True)
# Out:
# MultiEdgeDataView([('partager1973', 'PJCrowley', {'weight': 3.0}), ('RaoufRamahy', 'esraa_ali', {'weight': 1.0}), ('annaberlin1983', 'arwasm', {'weight': 1.0}), ('alexander_drake', 'Colvinius', {'weight': 2.0}), ('TwiddleEastNews', 'alaa', {'weight': 1.0}), ('TwiddleEastNews', 'ptypk', {'weight': 1.0}), ('TwiddleEastNews', 'sharifkouddous', {'weight': 2.0}), ('TwiddleEastNews', 'realrissa', {'weight': 1.0}), ('TwiddleEastNews', '_Sheri_Lynn_', {'weight': 1.0}), ('TwiddleEastNews', 'HerQ10', {'weight': 1.0}), ('TwiddleEastNews', 'stand4haq', {'weight': 2.0}), ('blackgothchick', 'blackballonline', {'weight': 3.0}), ('blackgothchick', 'blackgothchick', {'weight': 1.0}), ('MartinaArapovic', 'monaeltahawy', {'weight': 2.0}), ('DocsDaisyWoman', 'ArabRevolution', {'weight': 1.0}), ('sue_elise', 'BannedBlood', {'weight': 2.0}), ('Why0h562', 'Sandmonkey', {'weight': 9.0}), ('Why0h562', 'FreeLibyanman', {'weight': 2.0}), ('Why0h562', 'ashrafkhalil', {'weight': 1.0}), ('Why0h562', 'Tharwacolamus', {'weight': 1.0}), ('Why0h562', 'Ghonim', {'weight': 9.0}), ('Why0h562', 'OmarAlMukhtar', {'weight': 3.0}), ('isain', 'Barbieroja', {'weight': 4.0}), ('aladino30', 'Jotaviz', {'weight': 1.0}), ('robinite', 'HuffingtonPost', {'weight': 1.0}), ('foxq8', 'TMsartawi', {'weight': 25.0}), ('foxq8', 'lemlemz', {'weight': 16.0}), ('johnmcduffie', 'TravelGov', {'weight': 1.0}), ('AbdulrAlswaid', 'elnadeem', {'weight': 1.0}), ('AbdulrAlswaid', 'youssef_harraz', {'weight': 1.0}), ('poeticwayz', 'wendyknoxtn', {'weight': 2.0}), ('DrBaher', 'beshr', {'weight': 1.0}), ('FuatKircaali', 'MLeRoi', {'weight': 5.0}), ('FuatKircaali', 'sysconmedia', {'weight': 5.0}), ('FuatKircaali', 'GonzalezCarmen', {'weight': 8.0}), ('EmanuelSprung', 'JPBarlow', {'weight': 16.0}), ('SoulKirk', 'Christiversity', {'weight': 4.0}), ('SoulKirk', 'jmyers22', {'weight': 1.0}), ('SoulKirk', 'JesseNewhart', {'weight': 2.0}), ('dkfma47', 'iyad_elbaghdadi', {'weight': 4.0}), ('OpieRadio', '2Gs_Please', {'weight': 1.0}), ('barryegan', 'justimage', {'weight': 4.0}), ('affordanceinfo', 'BBCWorld', {'weight': 1.0}), ('lacitabar', 'RLFantastcMrFox', {'weight': 1.0}), ('Amnesty_Schweiz', 'amnesty_de', {'weight': 2.0}), ('harassmap', 'iHollaback', {'weight': 3.0}), ('harassmap', 'sarahcblake', {'weight': 3.0}), ('Titina_PJ', 'MitalJoshiGoel', {'weight': 2.0}), ('ChanelLaFlare', 'Wale', {'weight': 1.0}), ('ChanelLaFlare', 'DJ_SocialIntell', {'weight': 1.0}), ('ChanelLaFlare', 'TChristinex3', {'weight': 1.0}), ('_RellJones', 'D_BOY_SMURF', {'weight': 1.0}), ('Lore_TR', 'TIME', {'weight': 1.0}), ('thairston', 'Life_Quotesx', {'weight': 1.0}), ('RoberCamara', 'PabloZalba', {'weight': 1.0}), ('RoberCamara', 'JerzyBuzek', {'weight': 1.0}), ('saffroncloud', 'ianinegypt', {'weight': 3.0}), ('bridgeout', 'andersoncooper', {'weight': 2.0}), ('TrueMajority', 'beainchicago', {'weight': 4.0}), ('TrueMajority', 'g_oilman', {'weight': 4.0}), ('TrueMajority', 'maryel2', {'weight': 3.0}), ('Politica1984', 'BBCWorld', {'weight': 4.0}), ('mo7amedmousa', 'hkerdany', {'weight': 4.0}), ('FermaryTorres', 'PolarTercio', {'weight': 2.0}), ('mai_mohammed', 'seksek', {'weight': 4.0}), ('mai_mohammed', 'ZeinabSamir', {'weight': 1.0}), ('mai_mohammed', 'DailyNewsEgypt', {'weight': 1.0}), ('mai_mohammed', 'ANagib', {'weight': 6.0}), ('mai_mohammed', 'Raafatology', {'weight': 1.0}), ('mai_mohammed', 'mand0z', {'weight': 1.0}), ('mai_mohammed', 'Dima_Khatib', {'weight': 4.0}), ('mai_mohammed', 'EgyptRevolt2011', {'weight': 1.0}), ('mai_mohammed', 'wael', {'weight': 2.0}), ('mai_mohammed', 'SamehWagdy', {'weight': 6.0}), ('mai_mohammed', 'TheBoghdady', {'weight': 2.0}), ('mai_mohammed', 'rania_hafez', {'weight': 3.0}), ('mai_mohammed', 'mShady', {'weight': 1.0}), ('mai_mohammed', 'DostorNews', {'weight': 1.0}), ('mai_mohammed', 'eahram', {'weight': 1.0}), ('mai_mohammed', 'amnesty', {'weight': 3.0}), ('mai_mohammed', 'richardengelnbc', {'weight': 1.0}), ('abdozcom', 'taitos7', {'weight': 20.0}), ('abdozcom', 'abdozcom', {'weigh ...

# %%
# find cliques

print(list(nx.find_cliques(e)))
# Out:
# [['Redouan__', 'Rachid2009'], ['phijazin', 'kadwan'], ['phijazin', 'Egypt_Red_Free'], ['phijazin', 'lambada_'], ['phijazin', 'angelaperry'], ['phijazin', 'Waleed_Abdullah'], ['naranjero', 'mccartneyPedro'], ['sugarbean555', 'SmithSofia'], ['sugarbean555', 'UN'], ['sugarbean555', 'fieldproducer'], ['Kevb22', 'JUSRiiTE'], ['Kevb22', '_OlayOlivia'], ['naatymts', 'natyelematos'], ['GoGVOConference', 'GerardoUCV'], ['AntonioAche', 'Bombshell789'], ['DITO_DBB', 'vickyvette'], ['derrickrussell', 'HuffingtonPost'], ['Mobeca', 'Frospigliosi'], ['Mobeca', 'cubanitoencuba'], ['nassoskappa', 'HuffingtonPost'], ['aleid555', 'El_GindY'], ['HatemMejri', '3arabawy'], ['HatemMejri', 'ChrisOlc'], ['TomasChang', 'RobertoSmithP'], ['JonRolandFoster', 'tololy'], ['umelkher', 'panthera_f'], ['hmvh', 'aveltens'], ['ozgedelice', 'gayecosar'], ['claraguterres', 'nytimesworld'], ['Disco_Labirinto', 'cnnbrk'], ['aksharawi', 'ramadan'], ['listeningseeing', 'MortenHj'], ['ragsdariches', 'QueenWray100'], ['Ra_ed', 'tameradel'], ['Ra_ed', 'Mariam_KamaL'], ['EgyptRevolt2011', 'activistgirl'], ['EgyptRevolt2011', 'Penny_G'], ['EgyptRevolt2011', 'GossipGurL_X0X0'], ['EgyptRevolt2011', 'DontuTreadonMe'], ['EgyptRevolt2011', 'luishgomezo'], ['EgyptRevolt2011', 'Photographer90'], ['EgyptRevolt2011', 'Kitri1'], ['EgyptRevolt2011', 'bluereflex'], ['EgyptRevolt2011', 'mai_mohammed'], ['EgyptRevolt2011', 'ranaoboy'], ['yazham', 'ummhajarforpal2'], ['nibushibu', 'hisuix'], ['ejotasalda', 'yoanisanchez'], ['lydiastonemgmt', 'richstonemgmt'], ['Straub48', 'AJELive'], ['teatimest', 'SultanAlQassemi'], ['mabdelgany', 'AJELive'], ['hissar_simo', 'AJELive'], ['Bieberluuver4', 'justinbieber'], ['Bieberluuver4', 'todayshow'], ['shimaa_m', 'memam8'], ['shimaa_m', 'ahmedalsawi'], ['shimaa_m', 'libya2p0'], ['shimaa_m', 'NazQatar'], ['shimaa_m', 'DostorNews'], ['shimaa_m', 'Omar_Mokhtari'], ['abu_battal', 'HamidHossain'], ['bassemreda', 'ianinegypt'], ['bassemreda', 'jonjensen'], ['RockyjSquirrel2', 'AJEnglish'], ['RockyjSquirrel2', 'marwame'], ['RockyjSquirrel2', 'Anony_Ops'], ['crispe8168', 'monica_vv'], ['Resha_M_Ashraf', 'rezo007'], ['Resha_M_Ashraf', 'iDhooom'], ['pedrosoler', 'cn'], ['pedrosoler', 'Malnidawi'], ['MrChunks', 'VodafoneEgypt'], ['audiobrain', 'thegreenecon'], ['GlenGilmore', 'jaycbee'], ['al_andros', 'Sandmonkey'], ['romisyahril', 'AJELive'], ['lin_nah', 'DocRaccoon'], ['lin_nah', 'Dima_Khatib'], ['DinoDinosaur1', 'DariusMDeV'], ['Motheroffandon', 'CarelBruring'], ['Motheroffandon', 'Dima_Khatib'], ['mrwrighttc', 'donlemoncnn'], ['Ali_Bahnasawy', 'BalancedDogs'], ['Ali_Bahnasawy', 'majda72'], ['AdilRashid', 'AJArabic', 'feb17voices'], ['Raianeyaya', 'JoeUnfiltered'], ['TomasRosaBueno', 'acarvin'], ['TomasRosaBueno', 'LeShaque'], ['TomasRosaBueno', 'baraneshgh'], ['ItsTres', 'ilikeVans'], ['Hi_Im_Pretty', 'SuckMyWingo'], ['CharliePryor', 'mohamedahmos'], ['Glurch2891', 'baratunde'], ['Sheila_Nonato', 'cnnbrk'], ['ru4peace2', 'FreeLibyanman'], ['mohan_amin', 'htTweets'], ['habibh', 'antonevelynov'], ['habibh', 'y3ty'], ['habibh', 'paz_y_libertad', 'SamerKaram'], ['habibh', 'moalkhalifa'], ['habibh', 'neomaybach'], ['habibh', 'sarahnews'], ['habibh', 'nancylublin'], ['habibh', 'fatcouncillor'], ['habibh', 'seiffahmy'], ['habibh', '1anwi'], ['habibh', 'AmandaAzim'], ['habibh', 'treesarose'], ['habibh', 'MWK_1'], ['habibh', 'qhqpaliwallah'], ['habibh', 'KanaanManasrah'], ['habibh', 'akramquraishi'], ['habibh', 'FlotillaHyves'], ['habibh', 'BMKR92'], ['habibh', 'weredstar'], ['habibh', 'BunnyMellon'], ['habibh', 'katv'], ['habibh', 'muslimasoasis'], ['habibh', 'endeavoringE'], ['habibh', 'pdanijela7'], ['habibh', 'lauriecorona'], ['habibh', 'rimakader'], ['habibh', 'RulaKanaan'], ['habibh', 'Imans_'], ['habibh', 'haythamkhouja'], ['habibh', 'DoctoraAzma'], ['habibh', 'BaghdadBrian'], ['habibh', 'Fofe_'], ['habibh', '_sustain'], ['habibh', 'HopetoDream'], ['habibh', 'MustaphaZaizaa'], ['habibh', 'eclexia'], ['habibh', 'kragen'], ['habibh', 'shervin'], ['habibh', 'sun ...

# %%
list(e.edges)[:5]
# Out:
# [('partager1973', 'PJCrowley', 0),
#  ('RaoufRamahy', 'esraa_ali', 0),
#  ('annaberlin1983', 'arwasm', 0),
#  ('alexander_drake', 'Colvinius', 0),
#  ('TwiddleEastNews', 'alaa', 0)]

# %% [markdown]
# The book provides python examples using code that is deprecated, so I will try to move forward with notes outlining the concepts and incorporate the concepts into this week's assignment

# %% [markdown]
# **Island Method** splitting the giant component into smaller components, and areas with the strongest amount of **subcores** become their own components that can be analyzed separately.
#
# **Steps**
#
# 1. Define a function to apply a threshold that lets edges above a certain value through, and removes all others.
# 2. Next, define a function that computes evenly spaced thresholds and produces a list of networks at each level.
# 3. Isolate the biggest component and separate into subparts.

# %% [markdown]
# #### Subgraphs -- Ego Networks
#
# **Ego networks** are subnetworks that are centered on a certain node. On Facebook and LinkedIn, these are simply described as "your network" -- but you can only access your own ego networks, and can't do a broader survey.
#
# We derive ego networks by running a breadth-first search and limiting the depth (network radius) to a small value, usually not more than 3. While in traditional BFS we build a tree of links we followed to get to a node, to produce an ego network we capture *all* links between node's neighbors.

# %% [markdown]
# #### Extracting and Visualizing Ego Networks with Python
#
# A couple simple metrics stand out. Knowing the size of an ego network is important to understand the reach of the information that a person can transmit (or conversely, have access to).
#
# The other metric is called *clustering coefficient* -- essentially, it measures the proportion of you r friends that are also friends with each other.
#
# In ego networks, the interpretation is simple -- dense ego networks with a lot of mutual trust have a high clustering coefficient. Star networks with a single broadcast node and passive listeners have a low clustering coefficient.
#
# ### Triads
#
# **Triads** are three nodes interlinked in some way.
